# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.show()

# %%
print("the eigen vectors: ", pca.components_)
# Out:
# the eigen vectors:  [[ 0.36138659 -0.08452251  0.85667061  0.3582892 ]
#  [ 0.65658877  0.73016143 -0.17337266 -0.07548102]]

# %%
print("the eigen values: ", pca.explained_variance_)
# Out:
# the eigen values:  [4.22824171 0.24267075]

# %%
print("the covariance matrix is: \n", pca.get_covariance())
# Out:
# the covariance matrix is:
#  [[ 0.67918961 -0.03571514  1.2714061   0.53137208]
#  [-0.03571514  0.18303922 -0.32672469 -0.13706322]
#  [ 1.2714061  -0.32672469  3.12237957  1.28464626]
#  [ 0.53137208 -0.13706322  1.28464626  0.58834865]]
